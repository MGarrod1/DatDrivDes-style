# %%
from DDD_Network.plotting import DDD_plot
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# ## Karate Club Graph

# %%
G = nx.karate_club_graph()
nx.draw_circular(G)

# %%
len(G)
# Out:
# 34

# %%
DDD_plot(G)
plt.savefig("Example_Karate",facecolor='#313745')

# %% [markdown]
# ## ER graph

# %%
er_graph=nx.erdos_renyi_graph(100,0.005)
DDD_plot(er_graph)
plt.savefig("Example_ER",facecolor='#313745')
